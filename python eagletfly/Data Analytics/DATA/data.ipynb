# %%
import pandas as pd 
from pivottablejs import pivot_ui
from sklearn.datasets import load_iris

# %%
df=pd.read_csv('sports_infrastructure_facilities_available_at_tamilnadu_2017_18.csv',encoding='Latin-1')

# %%
df
# Out:
#     Sl.No                       Name of the District  \
# 0       1                                   Ariyalur
# 1       2                                   Ariyalur
# 2       3                                    Chennai
# 3       4                                    Chennai
# 4       5                                    Chennai
# 5       7                                    Chennai
# 6       8                                    Chennai
# 7       9                                    Chennai
# 8      10                                    Chennai
# 9      11                                    Chennai
# 10     12                                    Chennai
# 11     13                                    Chennai
# 12     14                                 Coimbatore
# 13     15                                  Cuddalore
# 14     16                                  Cuddalore
# 15     17                                 Dharmapuri
# 16     18                                 Dharmapuri
# ...

# %%
pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
